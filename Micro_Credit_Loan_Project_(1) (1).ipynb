# %%
# importing libraries
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import files
uplaoded = files.upload()
# Out:
#      <input type="file" id="files-3d288de4-fc65-4638-acac-1f5193b17ba3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3d288de4-fc65-4638-acac-1f5193b17ba3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Micro_credit_loan.csv to Micro_credit_loan (1).csv

# %% [markdown]
# Loading dataset

# %%
df=pd.read_csv("Micro_credit_loan.csv",sep='\t')
df
# Out:
#         Unnamed: 0  label       msisdn  ...  payback90  pcircle       pdate
# 0                1      0  21408I70789  ...  29.000000      UPW  20/07/2016
# 1                2      1  76462I70374  ...   0.000000      UPW  10/08/2016
# 2                3      1  17943I70372  ...   0.000000      UPW  19/08/2016
# 3                4      1  55773I70781  ...   0.000000      UPW  06/06/2016
# 4                5      1  03813I82730  ...   2.333333      UPW  22/06/2016
# ...            ...    ...          ...  ...        ...      ...         ...
# 209588      209589      1  22758I85348  ...   1.000000      UPW  17/06/2016
# 209589      209590      1  95583I84455  ...   1.000000      UPW  12/06/2016
# 209590      209591      1  28556I85350  ...   3.833333      UPW  29/07/2016
# 209591      209592      1  59712I82733  ...  10.500000      UPW  25/07/2016
# 209592      209593      1  65061I85339  ...   0.000000      UPW  07/07/2016
#
# [209593 rows x 37 columns]

# %%
# Checking columns in dataset
df.columns
# Out:
# Index(['Unnamed: 0', 'label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90',
#        'rental30', 'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'pcircle', 'pdate'],
#       dtype='object')

# %%
# Checking Information of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 37 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Unnamed: 0            209593 non-null  int64
#  1   label                 209593 non-null  int64
#  2   msisdn                209593 non-null  object
#  3   aon                   209593 non-null  float64
#  4   daily_decr30          209593 non-null  float64
#  5   daily_decr90          209593 non-null  float64
#  6   rental30              209593 non-null  float64
#  7   rental90              209593 non-null  float64
#  8   last_rech_date_ma     209593 non-null  float64
#  9   last_rech_date_da     209593 non-null  float64
#  10  last_rech_amt_ma      209593 non-null  int64
#  11  cnt_ma_rech30         209593 non-null  int64
#  12  fr_ma_rech30          209593 non-null  float64
#  13  sumamnt_ma_rech30     209593 non-null  float64
# ...

# %% [markdown]
# observation: No Null values present in dataset

# %%
# Checking shape of dataset
df.shape
# Out:
# (209593, 37)

# %%
# Checking datatypes
df.dtypes
# Out:
# Unnamed: 0                int64
# label                     int64
# msisdn                   object
# aon                     float64
# daily_decr30            float64
# daily_decr90            float64
# rental30                float64
# rental90                float64
# last_rech_date_ma       float64
# last_rech_date_da       float64
# last_rech_amt_ma          int64
# cnt_ma_rech30             int64
# fr_ma_rech30            float64
# sumamnt_ma_rech30       float64
# medianamnt_ma_rech30    float64
# medianmarechprebal30    float64
# cnt_ma_rech90             int64
# fr_ma_rech90              int64
# sumamnt_ma_rech90         int64
# medianamnt_ma_rech90    float64
# medianmarechprebal90    float64
# cnt_da_rech30           float64
# fr_da_rech30            float64
# cnt_da_rech90             int64
# fr_da_rech90              int64
# cnt_loans30               int64
# amnt_loans30              int64
# maxamnt_loans30         float64
# medianamnt_loans30      float64
# ...

# %%
# Checking Null values
df.isnull().sum()
# Out:
# Unnamed: 0              0
# label                   0
# msisdn                  0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# ...

# %%
# Checking Null values by using heatmap
import seaborn as sns
sns.heatmap(df.isnull())

# %%
df['pcircle'].value_counts()    # pcircle has Only one values so, no use of this feature
# Out:
# UPW    209593
# Name: pcircle, dtype: int64

# %%
df.drop('pcircle',axis=1,inplace=True)       # Dropping it

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)     # This contents only index values so dropping

# %%
df.drop('msisdn',axis=1,inplace=True)         # No use of this feature

# %%
df.drop('aon',axis=1,inplace=True)          # No use of mobile number

# %%
df['pdate']=pd.to_datetime(df['pdate'])       # Converting date object to datetime format

# %%
df_dates=pd.DataFrame()                     # Extracting month,year,day from Date
df_dates["month"]=df["pdate"].dt.month_name()
df_dates["year"]=df["pdate"].dt.year
df_dates["day"]=df['pdate'].dt.day_name()
df_dates
# Out:
#            month  year        day
# 0           July  2016  Wednesday
# 1        October  2016   Saturday
# 2         August  2016     Friday
# 3           June  2016     Monday
# 4           June  2016  Wednesday
# ...          ...   ...        ...
# 209588      June  2016     Friday
# 209589  December  2016    Tuesday
# 209590      July  2016     Friday
# 209591      July  2016     Monday
# 209592      July  2016   Thursday
#
# [209593 rows x 3 columns]

# %%
df_dates['year'].value_counts()
# Out:
# 2016    209593
# Name: year, dtype: int64

# %%
df_dates['month'].value_counts()
# Out:
# June         60434
# July         57779
# August       21080
# November      8092
# October       8050
# December      8028
# May           7989
# February      7839
# January       7824
# September     7717
# March         7607
# April         7154
# Name: month, dtype: int64

# %%
df_dates['day'].value_counts()
# Out:
# Thursday     34319
# Wednesday    33376
# Monday       29449
# Sunday       28881
# Tuesday      28508
# Friday       27765
# Saturday     27295
# Name: day, dtype: int64

# %%
df_dates.drop('year',axis=1,inplace=True)

# %%
df['pdate']=df_dates

# %%
df.isnull().sum()
# Out:
# label                   0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# pdate                   0
# dtype: int64

# %%
df.head()
# Out:
#    label  daily_decr30  daily_decr90  ...  payback30  payback90    pdate
# 0      0   3055.050000   3065.150000  ...  29.000000  29.000000     July
# 1      1  12122.000000  12124.750000  ...   0.000000   0.000000  October
# 2      1   1398.000000   1398.000000  ...   0.000000   0.000000   August
# 3      1     21.228000     21.228000  ...   0.000000   0.000000     June
# 4      1    150.619333    150.619333  ...   2.333333   2.333333     June
#
# [5 rows x 33 columns]

# %%
df.dtypes
# Out:
# label                     int64
# daily_decr30            float64
# daily_decr90            float64
# rental30                float64
# rental90                float64
# last_rech_date_ma       float64
# last_rech_date_da       float64
# last_rech_amt_ma          int64
# cnt_ma_rech30             int64
# fr_ma_rech30            float64
# sumamnt_ma_rech30       float64
# medianamnt_ma_rech30    float64
# medianmarechprebal30    float64
# cnt_ma_rech90             int64
# fr_ma_rech90              int64
# sumamnt_ma_rech90         int64
# medianamnt_ma_rech90    float64
# medianmarechprebal90    float64
# cnt_da_rech30           float64
# fr_da_rech30            float64
# cnt_da_rech90             int64
# fr_da_rech90              int64
# cnt_loans30               int64
# amnt_loans30              int64
# maxamnt_loans30         float64
# medianamnt_loans30      float64
# cnt_loans90             float64
# amnt_loans90              int64
# maxamnt_loans90           int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder() 
df['pdate']=le.fit_transform(df['pdate'].astype(str))

# %%
df.head()
# Out:
#    label  daily_decr30  daily_decr90  ...  payback30  payback90  pdate
# 0      0   3055.050000   3065.150000  ...  29.000000  29.000000      5
# 1      1  12122.000000  12124.750000  ...   0.000000   0.000000     10
# 2      1   1398.000000   1398.000000  ...   0.000000   0.000000      1
# 3      1     21.228000     21.228000  ...   0.000000   0.000000      6
# 4      1    150.619333    150.619333  ...   2.333333   2.333333      6
#
# [5 rows x 33 columns]

# %%
df.isnull().sum()
# Out:
# label                   0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# pdate                   0
# dtype: int64

# %%
# Checking statistical description
df.describe()
# Out:
#                label   daily_decr30  ...      payback90          pdate
# count  209593.000000  209593.000000  ...  209593.000000  209593.000000
# mean        0.875177    5381.402289  ...       4.321485       5.242656
# std         0.330519    9220.623400  ...      10.308108       2.572026
# min         0.000000     -93.012667  ...       0.000000       0.000000
# 25%         1.000000      42.440000  ...       0.000000       5.000000
# 50%         1.000000    1469.175667  ...       1.666667       5.000000
# 75%         1.000000    7244.000000  ...       4.500000       6.000000
# max         1.000000  265926.000000  ...     171.500000      11.000000
#
# [8 rows x 33 columns]

# %% [markdown]
# Observation: label maximum 1 and minimum 0
#              aon  maximum 999860.75 and minimum -48
#              daily_decr30 maximum 265926 and minimum -93.012
#              daily_decr90 maximum 320630 and minimum -93.012
#              rental30 maximum 198926.11 and minimum -23737.14
#              rental90 maximum 200148.11 and minimum -24720.58
#              last_rech_date_ma maximum 998650.37 and minimum -29
#              last_rech_date_da maximum 999171.80 and minimum -29
#              last_rech_amt_ma maximum 55000 and minimum 0
#              cnt_ma_rech30 maximum 203 and minimum 0
#              amnt_loans30 amximum 306 and minimum 0
#              maxamnt_loans30 maximum 99864.56 and minimum 0
#              medianamnt_loans30 maximum 3 and minimum 0
#              cnt_loans90 maximum 4997.51 and minimum 0
#              amnt_loans90 maximum 438 and minimum 0
#              maxamnt_loans90 maximum 12 and minimum 0
#              medianamnt_loans90 maximum 3 and minimum 0
#              payback30 maximum 171.50 and minimum 0
#              payback90 maximum 171.50 and minimum 0
#              pdate maximum 11 and minimum 0
#
#    As we can see above data skewness present in data. And Outliers also present.

# %%
# Checking Statistical correlation
df.corr()
# Out:
#                          label  daily_decr30  ...  payback90     pdate
# label                 1.000000      0.168298  ...   0.049183 -0.051133
# daily_decr30          0.168298      1.000000  ...   0.047175 -0.104668
# daily_decr90          0.166150      0.977704  ...   0.040800 -0.118170
# rental30              0.058085      0.442066  ...   0.095147 -0.057203
# rental90              0.075521      0.458977  ...   0.099501 -0.078542
# last_rech_date_ma     0.003728      0.000487  ...  -0.001583 -0.001686
# last_rech_date_da     0.001711     -0.001636  ...   0.000417  0.001500
# last_rech_amt_ma      0.131804      0.275837  ...  -0.014260 -0.006018
# cnt_ma_rech30         0.237331      0.451385  ...   0.017362 -0.000878
# fr_ma_rech30          0.001330     -0.000577  ...   0.000998  0.000156
# sumamnt_ma_rech30     0.202828      0.636536  ...  -0.012596 -0.010131
# medianamnt_ma_rech30  0.141490      0.295356  ...  -0.002861 -0.005685
# ...

# %% [markdown]
# Checking correlation by heatmap visualization

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(45,30))
sns.heatmap(df.corr(),annot=True)

# %% [markdown]
# Observation: aon, medianmarechprebal30, fr_da_rech30, fr_da_rech90, pdate are negatively correlated.

# %%
plt.figure(figsize=(25,10))
df.drop('label',axis=1).corrwith(df['label']).plot(kind='bar',grid=True)
plt.xticks(rotation=20)
plt.title("correlation with target variable")
# Out:
# Text(0.5, 1.0, 'correlation with target variable')

# %% [markdown]
# # Visualization

# %% [markdown]
# Univariate Analysis

# %%
#plt.figure(figsize=(25,10))
sns.countplot(x='label', data=df)
plt.title("count of label")
plt.show()
print(df['label'].value_counts())
# Out:
# 1    183431
# 0     26162
# Name: label, dtype: int64

# %% [markdown]
# Observation: 183431 Users paid back the credit amount within 5 days of issuing the loan.
#               26162 Users didnt paid back the credit amount within 5 days of issuing the loan.

# %%
plt.figure(figsize=(25,10))
sns.countplot(x='amnt_loans90', data=df)
plt.title("count of amnt_loans90")
plt.show()
print(df['amnt_loans90'].value_counts())
# Out:
# 6      69131
# 12     38908
# 18     23867
# 24     17216
# 30     12503
#        ...
# 360        1
# 426        1
# 396        1
# 438        1
# 342        1
# Name: amnt_loans90, Length: 69, dtype: int64

# %% [markdown]
#  Bivariate Analysis

# %%
plt.figure(figsize=(25,10))
sns.barplot(x='amnt_loans90',y='label',data=df)
plt.show()
print(df.groupby('amnt_loans90')['label'].value_counts())
print(df['amnt_loans90'].value_counts())
# Out:
# amnt_loans90  label
# 0             1         2043
# 6             1        50284
#               0        18847
# 12            1        34941
#               0         3967
#                        ...
# 396           1            1
# 402           1            1
# 408           1            4
# 426           1            1
# 438           1            1
# Name: label, Length: 95, dtype: int64
# 6      69131
# 12     38908
# 18     23867
# 24     17216
# 30     12503
#        ...
# 360        1
# 426        1
# 396        1
# 438        1
# 342        1
# Name: amnt_loans90, Length: 69, dtype: int64

# %%
plt.figure(figsize=(25,10))
sns.barplot(x='cnt_ma_rech30',y='label',data=df)
plt.show()
print(df.groupby('cnt_ma_rech30')['label'].value_counts())
print(df['cnt_ma_rech30'].value_counts())
# Out:
# cnt_ma_rech30  label
# 0              1        16856
#                0        11123
# 1              1        29561
#                0         7677
# 2              1        27936
#                         ...
# 84             1            1
# 91             1            1
# 99             1            1
# 115            1            1
# 203            1            1
# Name: label, Length: 103, dtype: int64
# 1      37238
# 2      31216
# 0      27979
# 3      25519
# 4      20258
#        ...
# 64         1
# 63         1
# 59         1
# 50         1
# 115        1
# Name: cnt_ma_rech30, Length: 71, dtype: int64

# %%
df.plot(kind='box', subplots=True, layout=(5,8), sharex=False, sharey=False)
plt.show()

# %% [markdown]
# # Checking Skewness

# %%
df.skew()
# Out:
# label                   -2.270254
# daily_decr30             3.946230
# daily_decr90             4.252565
# rental30                 4.521929
# rental90                 4.437681
# last_rech_date_ma       14.790974
# last_rech_date_da       14.814857
# last_rech_amt_ma         3.781149
# cnt_ma_rech30            3.283842
# fr_ma_rech30            14.772833
# sumamnt_ma_rech30        6.386787
# medianamnt_ma_rech30     3.512324
# medianmarechprebal30    14.779875
# cnt_ma_rech90            3.425254
# fr_ma_rech90             2.285423
# sumamnt_ma_rech90        4.897950
# medianamnt_ma_rech90     3.752706
# medianmarechprebal90    44.880503
# cnt_da_rech30           17.818364
# fr_da_rech30            14.776430
# cnt_da_rech90           27.267278
# fr_da_rech90            28.988083
# cnt_loans30              2.713421
# amnt_loans30             2.975719
# maxamnt_loans30         17.658052
# medianamnt_loans30       4.551043
# cnt_loans90             16.594408
# ...

# %% [markdown]
# # Removing Skewness

# %%
import numpy as np
for cols in df.columns:
    if df[cols].skew()>0.55:
        df[cols]=np.sqrt(df[cols])

# %%
for i in df.columns:
    if df[i].skew()>0.55:
        df[i]=np.cbrt(df[i])

# %%
#df['aon']=np.cbrt(df['aon'])
df['last_rech_date_da']=np.cbrt(df['last_rech_date_da'])
df['fr_da_rech90']=np.cbrt(df['fr_da_rech90'])
df['fr_da_rech30']=np.cbrt(df['fr_da_rech30'])
df['cnt_da_rech30']=np.cbrt(df['cnt_da_rech30'])

# %%
df.isnull().sum()
# Out:
# label                      0
# daily_decr30            1839
# daily_decr90            1839
# rental30                5628
# rental90                5929
# last_rech_date_ma       1315
# last_rech_date_da         14
# last_rech_amt_ma           0
# cnt_ma_rech30              0
# fr_ma_rech30               0
# sumamnt_ma_rech30          0
# medianamnt_ma_rech30       0
# medianmarechprebal30    1646
# cnt_ma_rech90              0
# fr_ma_rech90               0
# sumamnt_ma_rech90          0
# medianamnt_ma_rech90       0
# medianmarechprebal90    1730
# cnt_da_rech30              0
# fr_da_rech30               0
# cnt_da_rech90              0
# fr_da_rech90               0
# cnt_loans30                0
# amnt_loans30               0
# maxamnt_loans30            0
# medianamnt_loans30         0
# cnt_loans90                0
# amnt_loans90               0
# maxamnt_loans90            0
# medianamnt_loans90         0
# payback30                  0
# payback90                  0
# ...

# %% [markdown]
# Imputing Null values

# %%
list=['medianmarechprebal90','medianmarechprebal30','last_rech_date_da','last_rech_date_ma','rental90','rental30','daily_decr90','daily_decr30']
for i in list:
    df[i].fillna(df[i].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# label                   0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# pdate                   0
# dtype: int64

# %% [markdown]
# # Checking and removing outliers by zscore

# %%
from scipy.stats import zscore
import numpy as np

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))    
z
# Out:
# array([[2.64789583, 0.424064  , 0.38985835, ..., 1.69829428, 1.5454021 ,
#         0.09434453],
#        [0.37765836, 1.11608472, 1.06257996, ..., 0.96087434, 1.06245367,
#         1.84965284],
#        [0.37765836, 0.09668645, 0.06955375, ..., 0.96087434, 1.06245367,
#         1.64954242],
#        ...,
#        [0.37765836, 1.10302955, 1.05255332, ..., 0.95054602, 0.79883329,
#         0.09434453],
#        [0.37765836, 1.13285344, 1.08257229, ..., 0.96087434, 1.1391989 ,
#         0.09434453],
#        [0.37765836, 0.60161946, 0.56603976, ..., 0.96087434, 1.06245367,
#         0.09434453]])

# %%
threshold=3               #Identifying outlirs
print(np.where(z>3))
# Out:
# (array([     7,      7,     30, ..., 209587, 209591, 209591]), array([ 6, 20,  5, ..., 29,  6, 20]))

# %%
df1=df[(z<3).all(axis=1)]   #Removing outliers
df1
# Out:
#         label  daily_decr30  daily_decr90  ...  payback30  payback90  pdate
# 0           0      3.809223      3.811319  ...   1.752803   1.752803      5
# 1           1      4.792871      4.793052  ...   0.000000   0.000000     10
# 2           1      3.343884      3.343884  ...   0.000000   0.000000      1
# 3           1      1.663993      1.663993  ...   0.000000   0.000000      6
# 4           1      2.306642      2.306642  ...   1.151674   1.151674      6
# ...       ...           ...           ...  ...        ...        ...    ...
# 209586      1      5.213438      5.219863  ...   1.200937   1.157094      5
# 209588      1      2.309829      2.309829  ...   1.000000   1.000000      6
# 209589      1      1.824911      1.824911  ...   1.000000   1.000000      2
# 209590      1      4.774314      4.778420  ...   1.259921   1.251016      5
# 209592      1      4.061603      4.068428  ...   0.000000   0.000000      5
#
# [171376 rows x 33 columns]

# %%
from sklearn.preprocessing import power_transform    #Tranforming data
print(power_transform(df1,method='yeo-johnson'))
# Out:
# [[-2.72445714  0.45368565  0.43041175 ...  1.41894794  1.41627662
#   -0.10101337]
#  [ 0.3670456   1.11973809  1.068479   ... -1.03563651 -1.1289157
#    1.8435348 ]
#  [ 0.3670456   0.131794    0.11736681 ... -1.03563651 -1.1289157
#   -1.69261407]
#  ...
#  [ 0.3670456  -0.95851841 -0.95426153 ...  0.61870169  0.43831044
#   -1.28969823]
#  [ 0.3670456   1.10733508  1.0591413  ...  0.92186987  0.77823793
#   -0.10101337]
#  [ 0.3670456   0.62633742  0.59991132 ... -1.03563651 -1.1289157
#   -0.10101337]]

# %%
df.isnull().sum()
# Out:
# label                   0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# pdate                   0
# dtype: int64

# %% [markdown]
# # Splitting x and y variables

# %%
x=df.drop(['label'],axis=1)
x
# Out:
#         daily_decr30  daily_decr90  rental30  ...  payback30  payback90  pdate
# 0           3.809223      3.811319  2.457234  ...   1.752803   1.752803      5
# 1           4.792871      4.793052  3.931236  ...   0.000000   0.000000     10
# 2           3.343884      3.343884  3.107307  ...   0.000000   0.000000      1
# 3           1.663993      1.663993  2.328576  ...   0.000000   0.000000      6
# 4           2.306642      2.306642  3.212376  ...   1.151674   1.151674      6
# ...              ...           ...       ...  ...        ...        ...    ...
# 209588      2.309829      2.309829  3.207628  ...   1.000000   1.000000      6
# 209589      1.824911      1.824911  3.464222  ...   1.000000   1.000000      2
# 209590      4.774314      4.778420  4.246250  ...   1.259921   1.251016      5
# 209591      4.816706      4.822228  2.727635  ...   0.000000   1.479784      5
# 209592      4.061603      4.068428  2.801962  ...   0.000000   0.000000      5
#
# ...

# %%
y=df['label']
y
# Out:
# 0         0
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 209588    1
# 209589    1
# 209590    1
# 209591    1
# 209592    1
# Name: label, Length: 209593, dtype: int64

# %%
print(x.shape)
print(y.shape)
# Out:
# (209593, 32)
# (209593,)

# %%
from sklearn.preprocessing import StandardScaler   #scaling the data
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 0.424064  ,  0.38985835, -0.70847611, ...,  1.69829428,
#          1.5454021 , -0.09434453],
#        [ 1.11608472,  1.06257996,  0.72732277, ..., -0.96087434,
#         -1.06245367,  1.84965284],
#        [ 0.09668645,  0.06955375, -0.07525141, ..., -0.96087434,
#         -1.06245367, -1.64954242],
#        ...,
#        [ 1.10302955,  1.05255332,  1.03417216, ...,  0.95054602,
#          0.79883329, -0.09434453],
#        [ 1.13285344,  1.08257229, -0.44508298, ..., -0.96087434,
#          1.1391989 , -0.09434453],
#        [ 0.60161946,  0.56603976, -0.3726827 , ..., -0.96087434,
#         -1.06245367, -0.09434453]])

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from xgboost import XGBClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import r2_score
import warnings
warnings.filterwarnings('ignore')

# %%
# Splitting data into training and testing data
max_r_score=0
for r_state in range(42,101):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.22)

# %%
lr=LogisticRegression()
gnb=GaussianNB()
dtc=DecisionTreeClassifier()
rfc=RandomForestClassifier()
knn=KNeighborsClassifier()
xgb=XGBClassifier()
gbr=GradientBoostingClassifier()

# %%
models = []
models.append(('LogisticRegression',lr))
models.append(('GaussianNB',gnb))
models.append(('DecisionTreeClassifier',dtc))
models.append(('RandomForestClassifier',rfc))
models.append(('KNeighborsClassifier',knn))
models.append(('XGBClassifier',xgb))
models.append(('GradientBoostingClassifier',gbr))

# %%
Model = []
score = []

for name,model in models:
    print("**********",name,'**************')
    print('\n')
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.22)
    Model.append(name)
    model.fit(x_train,y_train)
    print(model)
    pre=model.predict(x_test)
    r2_scr=r2_score(y_test,pre)
    #print("r2_score corresponding to random state is" ,r2_scr)
    print('\n')
    print(accuracy_score(y_test,pre))
    print(confusion_matrix(y_test,pre))
    print(classification_report(y_test,pre))
# Out:
# ********** LogisticRegression **************
#
#
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)
#
#
# 0.8800069397757585
# [[  809  4885]
#  [  648 39769]]
#               precision    recall  f1-score   support
#
#            0       0.56      0.14      0.23      5694
#            1       0.89      0.98      0.93     40417
#
#     accuracy                           0.88     46111
#    macro avg       0.72      0.56      0.58     46111
# weighted avg       0.85      0.88      0.85     46111
#
# ********** GaussianNB **************
#
#
# GaussianNB(priors=None, var_smoothing=1e-09)
#
#
# 0.799136865390037
# [[ 3679  2015]
#  [ 7247 33170]]
#               precision    recall  f1-score   support
#
# ...

# %%
rf = RandomForestClassifier()
rf.fit(x_train, y_train)
rf_pre=rf.predict(x_test)
r2_scr=r2_score(y_test,rf_pre)
print(accuracy_score(y_test,rf_pre))
print(confusion_matrix(y_test,rf_pre))
print(classification_report(y_test,rf_pre))
# Out:
# 0.9148359393637093
# [[ 2636  3058]
#  [  869 39548]]
#               precision    recall  f1-score   support
#
#            0       0.75      0.46      0.57      5694
#            1       0.93      0.98      0.95     40417
#
#     accuracy                           0.91     46111
#    macro avg       0.84      0.72      0.76     46111
# weighted avg       0.91      0.91      0.91     46111

# %% [markdown]
# # Cross-Validation

# %%
from sklearn.model_selection import cross_val_score
for name,model in models:
    print("**********",name,'**************')
    print("\n")
    scores = cross_val_score(model,x_train,y_train,cv=10,scoring="accuracy")
    print("Scores:",scores)
    print("Mean:",scores.mean())
    print("Standard Deviation:",scores.std())
# Out:
# ********** LogisticRegression **************
#
#
# Scores: [0.87522173 0.87944217 0.87857842 0.87833374 0.87992415 0.87594813
#  0.87919011 0.87564228 0.87845608 0.87790555]
# Mean: 0.8778642362130302
# Standard Deviation: 0.0015863468204052988
# ********** GaussianNB **************
#
#
# Scores: [0.79656248 0.80151691 0.79985319 0.80040372 0.80358454 0.80211647
#  0.79887448 0.79875214 0.80309518 0.80015904]
# Mean: 0.800491815026956
# Standard Deviation: 0.0020406125106960946
# ********** DecisionTreeClassifier **************
#
#
# Scores: [0.87106245 0.87301976 0.86493761 0.87044287 0.86805725 0.87105456
#  0.86738439 0.87160509 0.86952532 0.86977   ]
# Mean: 0.8696859304978783
# Standard Deviation: 0.0022286228187652518
# ********** RandomForestClassifier **************
#
#
# Scores: [0.91228821 0.91638632 0.9127722  0.91632004 0.91717641 0.91356741
#  0.91485197 0.91350624 0.91442378 0.91350624]
# Mean: 0.9144798833218946
# Standard Deviation: 0.0015773938618337266
# ...

# %%
from sklearn.model_selection import GridSearchCV
rf=RandomForestClassifier(n_estimators=100)
param= {"criterion" : ["gini","entropy"]}
clf= GridSearchCV(estimator=rf,param_grid=param)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'criterion': 'entropy'}

# %%
rfr=RandomForestClassifier(n_estimators=100)
param= {"criterion" : ["entropy"]}
clf= GridSearchCV(estimator=rfr,param_grid=param)
rfr.fit(x_train,y_train)
rfr_pre=rfr.predict(x_test)
print(accuracy_score(y_test,rfr.predict(x_test)))
# Out:
# 0.914814252564464

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

# %%
auc=roc_auc_score(y_test,rfr_pre)
auc
# Out:
# 0.721387893086717

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(rf,x,y,cv=5,scoring='roc_auc').mean()
# Out:
# 0.8976390706342352

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(rfr,x,y,cv=5,scoring='roc_auc').mean()
# Out:
# 0.898561587461608

# %%
fpr,tpr,thresholds=roc_curve(y_test,rfr_pre)
plt.plot(fpr,tpr,color='orange',label='ROC')
plt.plot([0,1],[0,1],color='darkblue',linestyle='--',label='ROC curve(area=%0.3f)'%auc)
plt.legend()
plt.show()

# %%
from sklearn.externals import joblib
joblib.dump(rf,'rf_Micro_Credit_loan.obj')
# Out:
# ['rf_Micro_Credit_loan.obj']
